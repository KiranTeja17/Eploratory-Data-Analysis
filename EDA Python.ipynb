# %% [markdown]
# # EDA 2 Project
#
# ### Introduction:
#
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases.
#
# In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
#
# The different factors that influence the diabetes of a patient are:
#
# 1. Pregnancies - Number of times pregnant
#
# 2. Glucose - Plasma glucose concentration - 2 hours in an oral glucose tolerance test
#
# 3. BloodPressure - Diastolic blood pressure (mm Hg)
#
# 4. SkinThickness - Triceps skin fold thickness (mm)
#
# 5. Insulin - 2-Hour serum insulin (mu U/ml)
#
# 6. BMI - Body mass index
#
# 7. DiabetesPedigreeFunction - Diabetes pedigree function
#
# 8. Age - Age (years)
#
# 9. Outcome - Class variable (0 or 1)
#
# ### Aim :
#
# Our Aim in this project is to list out the important factors that affect the diabets.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Importing the excel files
df1 = pd.read_excel('diadata.xlsx')
df2 = pd.read_excel('variabledata.xlsx')

# %%
df1
# Out:
#      6.000    148.000  72.000   35.000   0.000    33.600   0.627    50.000   \
# 0        1.0     85.0     66.0     29.0      0.0     26.6    0.351     31.0
# 1        8.0    183.0     64.0      0.0      0.0     23.3    0.672     32.0
# 2        1.0     89.0     66.0     23.0     94.0     28.1    0.167     21.0
# 3        0.0    137.0     40.0     35.0    168.0     43.1    2.288     33.0
# 4        5.0    116.0     74.0      0.0      0.0     25.6    0.201     30.0
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 762     10.0    101.0     76.0     48.0    180.0     32.9    0.171     63.0
# 763      2.0    122.0     70.0     27.0      0.0     36.8    0.340     27.0
# 764      5.0    121.0     72.0     23.0    112.0     26.2    0.245     30.0
# 765      1.0    126.0     60.0      0.0      0.0     30.1    0.349     47.0
# 766      1.0     93.0     70.0     31.0      0.0     30.4    0.315     23.0
#
#      1.000
# 0        0.0
# 1        1.0
# 2        0.0
# ...

# %%
df2
# Out:
#                Variables used  \
# 0                 Pregnancies
# 1                     Glucose
# 2              Blood Pressure
# 3              Skin Thickness
# 4                     Insulin
# 5                         BMI
# 6  Diabetes Pedigree Function
# 7                         Age
# 8                     Outcome
#
#                                           Unnamed: 1
# 0                           Number of times pregnant
# 1  Plasma glucose concentration 2 hours in an ora...
# 2                   Diastolic blood pressure (mm Hg)
# 3                   Triceps skin fold thickness (mm)
# 4                     2-Hour serum insulin (mu U/ml)
# 5     Body mass index (weight in kg/(height in m)^2)
# 6                         Diabetes pedigree function
# 7                                        Age (years)
# 8  Class variable (0 or 1) 0 mean non-diabetic an...

# %%
# Adding columns to the dataset df1 as provided by the dataset df2 
df1.columns =['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'BMI', 'Diabetes Pedigree Function', 'Age', 'Outcome']

# %%
# Modified dataset with specific column variables are
df1.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0          1.0     85.0            66.0            29.0      0.0  26.6
# 1          8.0    183.0            64.0             0.0      0.0  23.3
# 2          1.0     89.0            66.0            23.0     94.0  28.1
# 3          0.0    137.0            40.0            35.0    168.0  43.1
# 4          5.0    116.0            74.0             0.0      0.0  25.6
#
#    Diabetes Pedigree Function   Age  Outcome
# 0                       0.351  31.0      0.0
# 1                       0.672  32.0      1.0
# 2                       0.167  21.0      0.0
# 3                       2.288  33.0      1.0
# 4                       0.201  30.0      0.0

# %%
df1.shape
# Out:
# (767, 9)

# %% [markdown]
# There are 767 rows and 9 columns in the given dataset

# %%
# Let's look at the datatypes of df1
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 767 non-null    float64
#  1   Glucose                     767 non-null    float64
#  2   Blood Pressure              767 non-null    float64
#  3   Skin Thickness              767 non-null    float64
#  4   Insulin                     767 non-null    float64
#  5   BMI                         767 non-null    float64
#  6   Diabetes Pedigree Function  767 non-null    float64
#  7   Age                         767 non-null    float64
#  8   Outcome                     767 non-null    float64
# dtypes: float64(9)
# memory usage: 54.1 KB

# %% [markdown]
# Let's change some of the columns into 'int64' datatype for better visualization

# %%
# Changing datatypes of some of the columns into integer functions
df1[['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'Age', 'Outcome']] =\
df1[['Pregnancies', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'Age', 'Outcome']].apply(lambda x : x.astype('int64'))

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Pregnancies                 767 non-null    int64
#  1   Glucose                     767 non-null    int64
#  2   Blood Pressure              767 non-null    int64
#  3   Skin Thickness              767 non-null    int64
#  4   Insulin                     767 non-null    int64
#  5   BMI                         767 non-null    float64
#  6   Diabetes Pedigree Function  767 non-null    float64
#  7   Age                         767 non-null    int64
#  8   Outcome                     767 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# Let's see if we have any null values
df1.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# Blood Pressure                0
# Skin Thickness                0
# Insulin                       0
# BMI                           0
# Diabetes Pedigree Function    0
# Age                           0
# Outcome                       0
# dtype: int64

# %% [markdown]
# As there are no null values we dont need to add or manipulate the original data

# %%
# Let's check the mean, median, mode and other arithematic functions from the dataset
df1.describe()
# Out:
#        Pregnancies     Glucose  Blood Pressure  Skin Thickness     Insulin  \
# count   767.000000  767.000000      767.000000      767.000000  767.000000
# mean      3.842243  120.859192       69.101695       20.517601   79.903520
# std       3.370877   31.978468       19.368155       15.954059  115.283105
# min       0.000000    0.000000        0.000000        0.000000    0.000000
# 25%       1.000000   99.000000       62.000000        0.000000    0.000000
# 50%       3.000000  117.000000       72.000000       23.000000   32.000000
# 75%       6.000000  140.000000       80.000000       32.000000  127.500000
# max      17.000000  199.000000      122.000000       99.000000  846.000000
#
#               BMI  Diabetes Pedigree Function         Age     Outcome
# count  767.000000                  767.000000  767.000000  767.000000
# mean    31.990482                    0.471674   33.219035    0.348110
# std      7.889091                    0.331497   11.752296    0.476682
# ...

# %% [markdown]
# There are '0's in the coulumns in which there souldn't be any.
#
# Let's see those columns wich have 0s in it and the count of 0s.

# %%
# Count of no.of zeros in each column
df1.eq(0).sum()
# Out:
# Pregnancies                   111
# Glucose                         5
# Blood Pressure                 35
# Skin Thickness                227
# Insulin                       373
# BMI                            11
# Diabetes Pedigree Function      0
# Age                             0
# Outcome                       500
# dtype: int64

# %% [markdown]
# Except Pregnancies and Outcome columns the rest of columns having 0 in them is meaningless.
#
# So lets remove the 0s and fill them with null value

# %%
# Replacing the 0s with NaN value i.e, 'Not a Null'
df1[['BMI', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'Age', 'Diabetes Pedigree Function']] = \
df1[['BMI', 'Glucose', 'Blood Pressure', 'Skin Thickness', 'Insulin', 'Age', 'Diabetes Pedigree Function']].replace(0, np.NaN)

# %%
# Now let's check the no. of 0s replaced with null values
df1.isna().sum()
# Out:
# Pregnancies                     0
# Glucose                         5
# Blood Pressure                 35
# Skin Thickness                227
# Insulin                       373
# BMI                            11
# Diabetes Pedigree Function      0
# Age                             0
# Outcome                         0
# dtype: int64

# %%
# As all the columns are numeric, we replace the null values with median
df1.fillna(df1.median(), inplace = True)
df1
# Out:
#      Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0              1     85.0            66.0            29.0    125.0  26.6
# 1              8    183.0            64.0            29.0    125.0  23.3
# 2              1     89.0            66.0            23.0     94.0  28.1
# 3              0    137.0            40.0            35.0    168.0  43.1
# 4              5    116.0            74.0            29.0    125.0  25.6
# ..           ...      ...             ...             ...      ...   ...
# 762           10    101.0            76.0            48.0    180.0  32.9
# 763            2    122.0            70.0            27.0    125.0  36.8
# 764            5    121.0            72.0            23.0    112.0  26.2
# 765            1    126.0            60.0            29.0    125.0  30.1
# 766            1     93.0            70.0            31.0    125.0  30.4
#
#      Diabetes Pedigree Function  Age  Outcome
# ...

# %%
# Checking for null values
df1.isnull().sum()
# Out:
# Pregnancies                   0
# Glucose                       0
# Blood Pressure                0
# Skin Thickness                0
# Insulin                       0
# BMI                           0
# Diabetes Pedigree Function    0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
df1.describe()
# Out:
#        Pregnancies     Glucose  Blood Pressure  Skin Thickness     Insulin  \
# count   767.000000  767.000000      767.000000      767.000000  767.000000
# mean      3.842243  121.621904       72.387223       29.100391  140.692308
# std       3.370877   30.443252       12.104527        8.794378   86.437570
# min       0.000000   44.000000       24.000000        7.000000   14.000000
# 25%       1.000000   99.500000       64.000000       25.000000  121.000000
# 50%       3.000000  117.000000       72.000000       29.000000  125.000000
# 75%       6.000000  140.000000       80.000000       32.000000  127.500000
# max      17.000000  199.000000      122.000000       99.000000  846.000000
#
#               BMI  Diabetes Pedigree Function         Age     Outcome
# count  767.000000                  767.000000  767.000000  767.000000
# mean    32.453716                    0.471674   33.219035    0.348110
# std      6.879539                    0.331497   11.752296    0.476682
# ...

# %% [markdown]
# All the 0s are filled with their respective mean
#
# Now we can proceed to visualization part as we completed the data cleaning process

# %%
# Plotting a bar graph to know the count of Diabetic people and non diabetic people
sns.set_style('whitegrid')
sns.countplot(x='Outcome', data = df1)
plt.title('Count of Outcome')
# Out:
# Text(0.5, 1.0, 'Count of Outcome')

# %% [markdown]
# As we can see the no.of people with diabetes is less than that of the people with no diabetes

# %%
# Plotting a pairplot to do multivariate analysis
sns.set_style('whitegrid')
sns.pairplot(df1, hue = 'Outcome', height = 3)
plt.show()

# %% [markdown]
# From all the scatter plots above we can see many outliers in all the variables.
#
# But these outliers are not meaningless and contribute to the data in some or the other way.

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# ##### Feature 1 - Age
#
# We divide the age into three groups
#
# 1. Ages between 0-25 are known as young
#
# 2. Ages between 25-50 are known as mid aged
#
# 3. Ages above 50 are known as Old

# %%
# Dividing the age group into three different groups
def set_age(row):
    if row["Age"] < 25:
        return "Young"
    elif row["Age"] >= 25 and row["Age"] <= 50:
        return "Mid_Aged"
    elif row["Age"] >= 51 and row["Age"] <= 80:
        return "Old"
df = df1.assign(Age_div=df.apply(set_age, axis=1))
df.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0            1     85.0            66.0            29.0    125.0  26.6
# 1            8    183.0            64.0            29.0    125.0  23.3
# 2            1     89.0            66.0            23.0     94.0  28.1
# 3            0    137.0            40.0            35.0    168.0  43.1
# 4            5    116.0            74.0            29.0    125.0  25.6
#
#    Diabetes Pedigree Function  Age  Outcome   Age_div
# 0                       0.351   31        0  Mid_Aged
# 1                       0.672   32        1  Mid_Aged
# 2                       0.167   21        0     Young
# 3                       2.288   33        1  Mid_Aged
# 4                       0.201   30        0  Mid_Aged

# %%
sns.countplot(x = 'Outcome', hue = 'Age_div', data= df)
plt.xlabel('Nature of diabetes')
plt.ylabel('No.of patients')
plt.title('Effect of age on diabetes')
# Out:
# Text(0.5, 1.0, 'Effect of age on diabetes')

# %% [markdown]
# Most of the mid aged women are affected with diabetes.

# %% [markdown]
# ##### Feature 2 : BMI
# The BMI is divided into the following categories:
#
#
# 1. Under 18.5 – you are considered underweight and possibly malnourished.
# 2. 18.5 to 24.9 – you are within a healthy weight range for young and middle-aged adults.
# 3. 25.0 to 29.9 – you are considered overweight.
# 4. Over 30 – you are considered obese.

# %%
# Defining the BMI and the condtion of the people
def set_bmi(row):
    if row["BMI"] < 18.5:
        return "Under"
    elif row["BMI"] >= 18.5 and row["BMI"] <= 24.9:
        return "Healthy"
    elif row["BMI"] >= 25 and row["BMI"] <= 29.9:
        return "Over"
    elif row["BMI"] >= 30:
        return "Obese"

# %%
# Adding the new column into the main dataset and assigning the new derived dataset into df
df = df.assign(BMI_derived=df.apply(set_bmi, axis=1))
df.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0            1     85.0            66.0            29.0    125.0  26.6
# 1            8    183.0            64.0            29.0    125.0  23.3
# 2            1     89.0            66.0            23.0     94.0  28.1
# 3            0    137.0            40.0            35.0    168.0  43.1
# 4            5    116.0            74.0            29.0    125.0  25.6
#
#    Diabetes Pedigree Function  Age  Outcome   Age_div BMI_derived
# 0                       0.351   31        0  Mid_Aged        Over
# 1                       0.672   32        1  Mid_Aged     Healthy
# 2                       0.167   21        0     Young        Over
# 3                       2.288   33        1  Mid_Aged       Obese
# 4                       0.201   30        0  Mid_Aged        Over

# %%
# Count plot for BMI_derived
sns.countplot(data=df, x = 'BMI_derived', label='Count')
plt.title('BMI of all women')
plt.xlabel('Body Mass Index')
plt.ylabel('No.of women')
df['BMI_derived'].value_counts()
# Out:
# Obese      482
# Over       179
# Healthy    102
# Under        4
# Name: BMI_derived, dtype: int64

# %% [markdown]
#  The following levels of BMI describe the condition of the person.
#
# BMI < 18.5 people are considered underweight and possibly malnourished.
#
# BMI from 18.5 to 24.9 people are within a healthy weight range for young and middle-aged adults.
#
# BMI from 25.0 to 29.9 people are considered overweight.
#
# BMI above 30 people are considered obese.

# %%
# Let's see how BMI affect Diabetes 
sns.catplot(x = 'BMI_derived',hue = 'Outcome', data=df, kind="count", height=5,aspect=.8 )
plt.title('Influence of BMI on diabetes')
plt.xlabel('Body Mass Index')
plt.ylabel('No.of women')
# Out:
# Text(27.86998697916667, 0.5, 'No.of women')

# %% [markdown]
# The most women who are over weight and obese have a very high chance in getting diagnosed with diabetes.

# %% [markdown]
# ##### Feature 3 - Insulin
#
# If insulin level (2-Hour serum insulin (mu U/ml)) is >= 16 and <= 166, then it is normal range else it is considered as Abnormal

# %%
# Defining the range in Insulin and adding that new column to the derived dataset 'df'
def set_insulin(row):
    if row["Insulin"] >= 16 and row["Insulin"] <= 166:
        return "Normal"
    else:
        return "Abnormal"
df = df.assign(INSULIN_der=df.apply(set_insulin, axis=1))
df.head()
# Out:
#    Pregnancies  Glucose  Blood Pressure  Skin Thickness  Insulin   BMI  \
# 0            1     85.0            66.0            29.0    125.0  26.6
# 1            8    183.0            64.0            29.0    125.0  23.3
# 2            1     89.0            66.0            23.0     94.0  28.1
# 3            0    137.0            40.0            35.0    168.0  43.1
# 4            5    116.0            74.0            29.0    125.0  25.6
#
#    Diabetes Pedigree Function  Age  Outcome   Age_div BMI_derived INSULIN_der
# 0                       0.351   31        0  Mid_Aged        Over      Normal
# 1                       0.672   32        1  Mid_Aged     Healthy      Normal
# 2                       0.167   21        0     Young        Over      Normal
# 3                       2.288   33        1  Mid_Aged       Obese    Abnormal
# 4                       0.201   30        0  Mid_Aged        Over      Normal

# %%
# Countplot for INSULIN_der
sns.countplot(data=df, x = 'INSULIN_der', label='Count')
plt.title('No.of women with Normal and Abnormal Insulin levels')
plt.xlabel('Insulin Levels')
plt.ylabel('No. of women')
df['INSULIN_der'].value_counts()
# Out:
# Normal      633
# Abnormal    134
# Name: INSULIN_der, dtype: int64

# %% [markdown]
# The no.of women having normal insulin levels are 260 and that of abnormal level of insul are 507

# %%
# Let's see how insulin levels affect Diabetes 
sns.catplot(x = 'INSULIN_der',hue = 'Outcome', data=df, kind="count", height=5,aspect=.8 )
plt.title('Influence of Insulin levels on diabetes')
plt.xlabel('Insullin Levels')
plt.ylabel('No.of women')
# Out:
# Text(27.86998697916667, 0.5, 'No.of women')

# %% [markdown]
# The influence of Abnormal insulin levels is very high on diabetes, women with abnormal insulin levels have around 41% chance of diagnosing with diabetes.
#
# Whereas the women with normal insulin levels have a probability of 0.23 to get diagnosed with diabetes.

# %%
# Boxplot of Age and Insulin leveles
sns.boxplot(x = 'Age',y = 'INSULIN_der',hue = 'Outcome', data=df)
plt.title('Influence of Age and Insulin levels on diabetes')
plt.xlabel('Age of the patient')
plt.ylabel('Insulin Levels')
# Out:
# Text(0, 0.5, 'Insulin Levels')

# %% [markdown]
# From the above plot it is observed that the people within the age 25-45 are more prone to diabetes with normal insulin levels whereas the people with abnormal insulin levels are more prone to diabetes above the age 28.

# %%
# Boxplot to find the relation between Age and BMI on diabetes
sns.boxplot(x="Age", y="BMI_derived", hue = "Outcome", data = df)
plt.xlabel('Age of the patient')
plt.ylabel('Body Mass Index')
plt.title('Influence of Age and BMI in diabetes')
# Out:
# Text(0.5, 1.0, 'Influence of Age and BMI in diabetes')

# %% [markdown]
# From the above plot it is observed that patients who are obese as per BMI index are more diabetic in early age of 25 where as patients who are overweight are prone to diabetes in early 30's
#
# There are also some instances where the uneder weight patients are diagnosed with diabetes. This may be because of the lack of nutrients they recieve and also because of weak immune system that is generally observed in the underweight patients.
#
# It is also evident that healthy patients as per BMI index are mostly diabetic above the age of 45 and it can be because of a lot of factors like genetics, unhealthy lifestyle, lack of good diet, no exerrcise, etc,.

# %%
# Let's see the affect of glucose levels on diabetes
sns.scatterplot(x="Age", y="Glucose", hue = "Outcome", data = df)
plt.xlabel('Age of the patient')
plt.ylabel('Glucose levles')
plt.title('Influence of Age and Glucose in diabetes')
# Out:
# Text(0.5, 1.0, 'Influence of Age and Glucose in diabetes')

# %% [markdown]
# From the above plot the following observations are made:
#
# 1.Most of the non diabetic patients across all ages have their Glucose levels between 70 and 140. This range can be considered as suggested glucose level for patients of any age.
#
# 2.Most of the diabetic patients whose glucose levels are above 140 are diabetic. Also the patients whose age is above 35 are more prone to diabetes with any glucose levels.

# %% [markdown]
# Most of the patients who are mid aged are diagnosed with diabetes.

# %%
# Boxplot of Blood pressure and BMI
sns.boxplot(x="Blood Pressure", y="BMI_derived", hue = "Outcome", data = df)
plt.xlabel('Blood Pressure')
plt.ylabel('Age of the patient')
plt.title('Influence of Age and Blood Pressure in diabetes')
# Out:
# Text(0.5, 1.0, 'Influence of Age and Blood Pressure in diabetes')

# %% [markdown]
# Most of the diabetic patients are of obese as per BMI index having a median blood pressure of over 70 whereas patients under weight have a blood pressure median of over 85.

# %%
# Scatterplot of Skin thickness and Outcome
sns.scatterplot(x="Skin Thickness", y = "Outcome",hue = 'Age_div', data = df)
plt.xlabel('Skin Thickness')
plt.ylabel('Nature of Diabetes')
plt.title('Influence of Skin Thickness diabetes')
# Out:
# Text(0.5, 1.0, 'Influence of Skin Thickness diabetes')

# %% [markdown]
# The skin thickness variable doesn't provide us with any stron evidence of influence on diabetes, this is because all the patients having skin thickness of any range can be prone to diabetes.
#
# So we can say that Skin Thickness is not an important factor while understanding the causes of diabetes.

# %% [markdown]
# # Conclusion
#
# The most contributing factors for diabetes from the given data by the data are:
#
# 1. Glucose : The glucose levels from 70-140 is considered as healthy and less prone to diabetes.
#
# 2. Blood Pressure : Most of the diabetic patients are of obese as per BMI index having a median blood pressure of over 70 whereas patients under weight have a blood pressure median of over 85.
#
# 3. Age : Most of the mid aged women are affected with diabetes.
#
# 4. Glucose Levels : Most of the non diabetic patients across all ages have their Glucose levels between 70 and 140. This range can be considered as suggested glucose level for patients of any age.Most of the diabetic patients whose glucose levels are above 140 are diabetic. Also the patients whose age is above 35 are more prone to diabetes with any glucose levels.
#
# 5. Insulin : The people within the age 25-45 are more prone to diabetes with normal insulin levels whereas the people with abnormal insulin levels are more prone to diabetes above the age 28.
#
# 6. BMI : The most women who are over weight and obese have a very high chance in getting diagnosed with diabetes.
